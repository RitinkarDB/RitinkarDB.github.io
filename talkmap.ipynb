# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 5.2 MB/s eta 0:00:00
# Collecting pygithub
#   Downloading PyGithub-2.3.0-py3-none-any.whl (354 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.0 MB/s eta 0:00:00
# Collecting pynacl>=1.4.0
#   Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.9/349.9 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pygithub->getorg) (4.4.0)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pygithub->getorg) (2.4.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pygithub->getorg) (1.26.14)
# Requirement already satisfied: requests>=2.14.0 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pygithub->getorg) (2.28.1)
# Collecting Deprecated
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.7.0 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from retrying->getorg) (1.16.0)
# Requirement already satisfied: cryptography>=3.3.1 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (39.0.1)
# Requirement already satisfied: cffi>=1.4.1 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.15.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from Deprecated->pygithub->getorg) (1.14.1)
# Requirement already satisfied: pycparser in /Users/ritinkardasbhaumik/anaconda3/lib/python3.10/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Installing collected packages: retrying, geographiclib, Deprecated, pynacl, geopy, pygithub, getorg
# Successfully installed Deprecated-1.2.14 geographiclib-2.0 geopy-2.4.1 getorg-0.3.1 pygithub-2.3.0 pynacl-1.5.0 retrying-1.3.4
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#
# File ~/anaconda3/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.4.1" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       7     loc_end = lines_trim.find('"')
#       8     location = lines_trim[:loc_end]
# ---> 11 location_dict[location] = geocoder.geocode(location)
#      12 print(location, "\n", location_dict[location])
#
# NameError: name 'geocoder' is not defined

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
